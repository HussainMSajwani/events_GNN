# %%
from imports.ASLDataset import ASLDataset
from torch_geometric.utils import to_networkx

#dl = DataLoader()
data = ASLDataset(letters=['a'])
torch_graph = data.get(1)


G = to_networkx(torch_graph, to_undirected=True)
G
# Out:
# Processing...
# processing: 100%|███████████████████████▉| 4199/4200 [00:00<00:00, 94569.58it/s]
# Done!

# %%
torch_graph
# Out:
# Data(x=[3099, 1], y=0, pos=[3099, 3], edge_index=[2, 77261], edge_attr=[77261, 3])

# %%
77261/3099
# Out:
# 24.930945466279447

# %%
import matplotlib.pyplot as plt

plt.scatter(torch_graph['pos'][:,0], torch_graph['pos'][:,1])

# %%
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 nx.draw(G)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:301, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     298 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     300 if pos is None:
# --> 301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
#     304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# ...

# %%
import networkx as nx

nx.diameter(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import networkx as nx
# ----> 3 nx.diameter(G)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/algorithms/distance_measures.py:388, in diameter(G, e, usebounds)
#     386     return _extrema_bounding(G, compute="diameter")
#     387 if e is None:
# --> 388     e = eccentricity(G)
#     389 return max(e.values())
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/algorithms/distance_measures.py:347, in eccentricity(G, v, sp)
#     345         else:
#     346             msg = "Found infinite path length because the graph is not" " connected"
# --> 347         raise nx.NetworkXError(msg)
#     349     e[n] = max(length.values())
#     351 if v in G:
#
# NetworkXError: Found infinite path length because the graph is not connected

# %%
nx.is_connected(G)
# Out:
# False

# %%
nx.number_connected_components(G)
# Out:
# 84

# %%
nx.k_components(G)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 nx.k_components(G)
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/utils/decorators.py:845, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     844 def func(*args, __wrapper=None, **kwargs):
# --> 845     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 12:4, in argmap_k_components_9(G, flow_func)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~/miniconda3/envs/torch/lib/python3.8/site-packages/networkx/algorithms/connectivity/kcomponents.py:131, in k_components(G, flow_func)
#     129     k_components[k].append(set(B))
#     130 # Perform cuts in a DFS like order.
# ...
